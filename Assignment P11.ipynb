# %% [markdown]
# ## Assignment P11
#
# In the previous section is a link to the matplotlib documentation. Explore the example plots and reproduce a least three of them in your own Jupyterlab environment. Create one of each of these types:
#
# - line plot
# - scatter plot
# - bar plot

# %% [markdown]
# ### Line plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np
data = np.random.randn(1000)

# %%
x= np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x), '-p', label='sin(x)')
plt.plot(x, np.cos(x), '--b', label='cos(x)')
plt.title('Line Plot')
plt.xlabel('X')
plt.axis('equal')

plt.legend();

# %%
ax = plt.axes()
ax.plot(x, np.sin(x),'-', label='sin(x)')
ax.plot(x, np.cos(x),':',label='cos(x)')
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', 
       title='A Simple Line Plot');

# %% [markdown]
# ### scatter plot

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[1], features[2],  alpha=0.5,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[1])
plt.ylabel(iris.feature_names[2]);

# %% [markdown]
# ### bar plot

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-4, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.5, normed=True, bins=50)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
# Out:
# /Users/saraabdulrahman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   import sys
# /Users/saraabdulrahman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#
# /Users/saraabdulrahman/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   if __name__ == '__main__':
